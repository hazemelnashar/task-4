# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %% [markdown]
# >Reading data set and showing first 5 Rows:

# %%
df = pd.read_csv('Wuzzuf_Jobs.csv')
df.head(5)
# Out:
#                                Title                Company    Location  \
# 0             Customer Service Agent       Johnson Controls   New Cairo
# 1                  Marketing Manager  SYE English Community       Dokki
# 2  Medical Representative Heliopolis        So Value Pharma       Cairo
# 3          Order Handling Specialist       Johnson Controls   New Cairo
# 4                        Storekeeper           Confidential       Cairo
#
#         Type        Level         YearsExp Country  \
# 0  Full Time  Entry Level   1-3 Yrs of Exp   Cairo
# 1  Full Time      Manager  5-10 Yrs of Exp    Giza
# 2  Full Time  Entry Level   0-5 Yrs of Exp   Egypt
# 3  Full Time  Experienced   3-5 Yrs of Exp   Cairo
# 4  Full Time  Experienced    3+ Yrs of Exp   Egypt
#
#                                               Skills
# 0  Call Center, Customer Support, Customer Care, ...
# 1  Market Research, Social Media, Online Marketin...
# 2  Cardio-metabolic, Sales Skills, Sales Target, ...
# ...

# %%
df.describe()
# Out:
#              Title       Company Location       Type        Level  \
# count         4380          4380     4380       4380         4380
# unique        2965          1534      162          6            9
# top     Accountant  Confidential    Cairo  Full Time  Experienced
# freq            57           590      563       4168         2198
#
#               YearsExp Country  \
# count             4380    4380
# unique             101      42
# top     1-3 Yrs of Exp   Cairo
# freq               414    2230
#
#                                                    Skills
# count                                                4380
# unique                                               4227
# top     Corporate Sales, Real Estate, Advertising, Mar...
# freq                                                   12

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4380 entries, 0 to 4379
# Data columns (total 8 columns):
# Title       4380 non-null object
# Company     4380 non-null object
# Location    4380 non-null object
# Type        4380 non-null object
# Level       4380 non-null object
# YearsExp    4380 non-null object
# Country     4380 non-null object
# Skills      4380 non-null object
# dtypes: object(8)
# memory usage: 273.9+ KB

# %%
df.shape
# Out:
# (4380, 8)

# %%
df.drop_duplicates(inplace=True)
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (4377, 8)

# %%
df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4377 entries, 0 to 4379
# Data columns (total 8 columns):
# Title       4377 non-null object
# Company     4377 non-null object
# Location    4377 non-null object
# Type        4377 non-null object
# Level       4377 non-null object
# YearsExp    4377 non-null object
# Country     4377 non-null object
# Skills      4377 non-null object
# dtypes: object(8)
# memory usage: 307.8+ KB

# %%
Jobs_companies = df['Company'].value_counts()[:5]
print(Jobs_companies)
# Out:
# Confidential    590
# Mishkat Nour     39
# Expand Cart      35
# EGIC             34
# Aqarmap.com      25
# Name: Company, dtype: int64

# %%
plt.subplots(figsize=(30,10))
companies = ['Confidential','Mishkat Nour', 'Expand Cart', 'EGIC', 'Aqarmap.com']
plt.pie(Jobs_companies, labels=companies, wedgeprops={'edgecolor': 'black'}, autopct ='%1.2f%%', explode =(0.2,0.1,0.1,0.1,0.1),shadow = True )
plt.title("Jobs_companies")
plt.legend();

# %%
x = df['Title'].value_counts()[:10]
print(x)
# Out:
# Accountant                      57
# Sales Representative            47
# Graphic Designer                43
# Digital Marketing Specialist    26
# Sales Manager                   25
# Social Media Specialist         24
# Receptionist                    23
# Executive Secretary             21
# Sales Executive                 18
# Marketing Specialist            17
# Name: Title, dtype: int64

# %%
plt.subplots(figsize=(10,10))
plt.barh(x.index,x,height = 0.5, color='green', edgecolor="black", linewidth=0.1);
plt.title("MOST POPULAR JOBS")
plt.ylabel("JOBS")
plt.xlabel("DEMAND");

# %%
y = df['Location'].value_counts()[:10]
print(y)
# Out:
#  Cairo             563
#  Maadi             524
#  New Cairo         520
#  Nasr City         424
#  6th of October    282
#  Heliopolis        247
#  Mohandessin       140
#  Dokki             140
#  Alexandria        130
#  Giza              126
# Name: Location, dtype: int64

# %%
plt.subplots(figsize=(15,7))
plt.bar(y.index,y,width = 0.4, color='blue');
plt.title("MOST POPULAR LOCATIONS")
plt.ylabel("RATE")
plt.xlabel("CITIES");

# %%
z = df['Skills'].value_counts()[:5]
print(z)
# Out:
# Corporate Sales, Real Estate, Advertising, Marketing, Sales Skills, Insurance, Sales Target, Outdoor Sales, Telesales, Property       12
# Logistics, SAP, Inventory, Store Keeping, Logistics/Supply Chain                                                                      11
# Sales Skills, Sales Target, Customer Services, Customer Care, Retail, Collection, Distribution, Selling Skills, Negotiation Skills    10
# Medical, Training, Family Palnning, Contraceptives, MoHP, Medical/Healthcare, Training/Instructor                                      9
# Finance, Sales Accounting, Commerce, Budget, Reporting, Accounting/Finance                                                             9
# Name: Skills, dtype: int64

# %%
plt.subplots(figsize=(30,10))
groups = ['Group_1','Group_2', 'Group_3', 'Group_4', 'Group_5']
plt.pie(z, labels=groups, wedgeprops={'edgecolor': 'black'}, autopct ='%1.2f%%', explode =(0.2,0.1,0.1,0.1,0.1),shadow = True )
plt.title("Skills");
plt.legend();

# %%
# split column into multiple columns by delimiter 
Seperated_Skills= df['Skills'].str.split(',', expand=True)

# %%
Seperated_Skills.shape
# Out:
# (4377, 17)

# %%
Seperated_Skills.head(5)
# Out:
#                   0                  1                                      2  \
# 0       Call Center   Customer Support                          Customer Care
# 1   Market Research       Social Media                       Online Marketing
# 2  Cardio-metabolic       Sales Skills                           Sales Target
# 3    Supply Officer     Supply Planner   Procurement and Logistics Specialist
# 4       Warehousing       Storekeeping                 Logistics/Supply Chain
#
#                               3                             4  \
# 0                       English      Customer Service/Support
# 1          Marketing Management                Marketing Plan
# 2              Customer Service                 Customer Care
# 3   Order Management Specialist   Order Processing Specialist
# 4                          None                          None
#
#                    5           6                7         8     9    10    11  \
# ...

# %%
#remove duplicated data
Seperated_Skills.drop_duplicates(inplace=True)

# %%
Seperated_Skills.shape
# Out:
# (4227, 17)

# %%
Seperated_Skills.head(5)
# Out:
#                   0                  1                                      2  \
# 0       Call Center   Customer Support                          Customer Care
# 1   Market Research       Social Media                       Online Marketing
# 2  Cardio-metabolic       Sales Skills                           Sales Target
# 3    Supply Officer     Supply Planner   Procurement and Logistics Specialist
# 4       Warehousing       Storekeeping                 Logistics/Supply Chain
#
#                               3                             4  \
# 0                       English      Customer Service/Support
# 1          Marketing Management                Marketing Plan
# 2              Customer Service                 Customer Care
# 3   Order Management Specialist   Order Processing Specialist
# 4                          None                          None
#
#                    5           6                7         8     9    10    11  \
# ...

# %%
#rename columns of data frame: 
Seperated_Skills.columns = ['Skill_1', 'Skill_2', 'Skill_3', 'Skill_4', 'Skill_5', 'Skill_6', 'Skill_7', 'Skill_8', 'Skill_9', 'Skill_10', 'Skill_11', 'Skill_12', 'Skill_13', 'Skill_14', 'Skill_15', 'Skill_16', 'Skill_17']

# %%
Seperated_Skills.head(5)
# Out:
#             Skill_1            Skill_2                                Skill_3  \
# 0       Call Center   Customer Support                          Customer Care
# 1   Market Research       Social Media                       Online Marketing
# 2  Cardio-metabolic       Sales Skills                           Sales Target
# 3    Supply Officer     Supply Planner   Procurement and Logistics Specialist
# 4       Warehousing       Storekeeping                 Logistics/Supply Chain
#
#                         Skill_4                       Skill_5  \
# 0                       English      Customer Service/Support
# 1          Marketing Management                Marketing Plan
# 2              Customer Service                 Customer Care
# 3   Order Management Specialist   Order Processing Specialist
# 4                          None                          None
#
#              Skill_6     Skill_7          Skill_8   Skill_9 Skill_10 Skill_11  \
# ...

# %% [markdown]
# ### PERFORMING ANALYSIS ON EACH COLUMN TO FIND THE MOST POPULER SKILLS :

# %%
s1 = Seperated_Skills['Skill_1'].value_counts()[:10]
s1
# Out:
# Sales Skills                   265
# Information Technology (IT)    160
# Computer Science               146
# Sales Target                   117
# Finance                        108
# Administration                  92
# Customer Service                90
# Accounting                      88
# Males Only                      86
# Social Media                    81
# Name: Skill_1, dtype: int64

# %%
plt.subplots(figsize=(10,10))
plt.barh(s1.index,s1,height = 0.5, color='magenta', edgecolor="black", linewidth=0.1);
plt.title("MOST REQUIRED SKILLS ")
plt.ylabel("SKILLS")
plt.xlabel("RATE");

# %%
s2 = Seperated_Skills['Skill_2'].value_counts()[:10]
s2
# Out:
#  Sales Target                   166
#  Sales Skills                   163
#  Computer Science               131
#  Customer Service               113
#  Information Technology (IT)    101
#  Finance                         85
#  Microsoft Office                84
#  Software Development            79
#  English                         72
#  Financial Analysis              61
# Name: Skill_2, dtype: int64

# %%
plt.subplots(figsize=(10,10))
plt.barh(s2.index,s2,height = 0.5, color='tomato', edgecolor="black", linewidth=0.1);
plt.title("MOST REQUIRED SKILLS ")
plt.ylabel("SKILLS")
plt.xlabel("RATE");

# %%
s3 = Seperated_Skills['Skill_3'].value_counts()[:10]
s3
# Out:
#  English                        152
#  Sales Target                   125
#  Sales Skills                   111
#  Microsoft Office               107
#  Customer Service                99
#  Computer Science                97
#  Software Development            84
#  Financial Analysis              74
#  Information Technology (IT)     69
#  Communication Skills            68
# Name: Skill_3, dtype: int64

# %%
plt.subplots(figsize=(10,10))
plt.barh(s3.index,s3,height = 0.5, color='violet', edgecolor="black", linewidth=0.1);
plt.title("MOST REQUIRED SKILLS ")
plt.ylabel("SKILLS")
plt.xlabel("RATE");

# %%
s4 = Seperated_Skills['Skill_4'].value_counts()[:10]
s4
# Out:
#  English                        236
#  Microsoft Office               103
#  Customer Service                99
#  Communication Skills            99
#  Sales Target                    80
#  Computer Science                75
#  Administration                  57
#  Information Technology (IT)     56
#  Sales Skills                    56
#  Financial Analysis              53
# Name: Skill_4, dtype: int64

# %%
plt.subplots(figsize=(10,10))
plt.barh(s4.index,s4,height = 0.5, color='darkcyan', edgecolor="black", linewidth=0.1);
plt.title("MOST REQUIRED SKILLS ")
plt.ylabel("SKILLS")
plt.xlabel("RATE");

# %% [markdown]
# ##### BY REPEATING THIS ON ALL COLUMNS WILL HAVE THE MOST POPULER SKILLS  :

# %% [markdown]
# - Sales Skills  265
# - English  236
# - Sales Target 166
# - Information Technology (IT)  160
# - Microsoft Office  103

# %%
d = np.array([265,236,166,160,103])
mylabels = ["Sales Skills", "English", "Sales Target", "Information Technology","Microsoft Office"]
plt.subplots(figsize=(25,10))
plt.pie(d, labels=mylabels, wedgeprops={'edgecolor': 'black'}, autopct ='%1.2f%%', explode =(0.2,0.1,0.1,0.1,0.1),shadow = True )
plt.title("Skills");
plt.legend();
